# %%
#importing python libraries
import os
import sys
import torch
import syft as sy
from syft import Variable as Var
from syft import nn
from syft import optim

# %%
module_path = os.path.abspath(os.path.join('./PySyft'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# creating hook instance which will overload all operations required for federate learning activity
hook = sy.TorchHook()
host_machine = hook.local_worker

mobile_device_1 = sy.VirtualWorker(id="mobile_device_1",hook=hook)
mobile_device_2= sy.VirtualWorker(id="mobile_device_2",hook=hook)

host_machine.add_worker(mobile_device_1)
host_machine.add_worker(mobile_device_2)
# Out:
# WARNING:root:Worker mobile_device_1 already exists. Replacing old worker which could cause unexpected behavior
# WARNING:root:Worker mobile_device_2 already exists. Replacing old worker which could cause unexpected behavior

# %%
# importing dataset

#information about dataset
#Predictor Variable: Gender(Male: 1 , Female: 0) ,Age ,Tenure(Time period of the account),
#                    Balance(Amount in the account) ,HasCrCard(has credit card(yes: 1 , no: 0))
#                    IsActiveMember(Active status(yes: 1 , no: 0)) ,Estimated salary
#Target Variable:    Exited(has exited(yes:1 , no: 0))
import pandas as pd
dataset_read=pd.read_csv("bank_dataset.csv", sep=',')
dataset_read.head()
# Out:
#    Gender  Age  Tenure    Balance  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0   42       2       0.00          1               1        101348.88
# 1       0   41       1   83807.86          0               1        112542.58
# 2       0   42       8  159660.80          1               0        113931.57
# 3       0   39       1       0.00          0               0         93826.63
# 4       0   43       2  125510.82          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
dataset_read=dataset_read[dataset_read.Balance!=0.00]

# %%
dataset_read.head()
# Out:
#    Gender  Age  Tenure    Balance  HasCrCard  IsActiveMember  EstimatedSalary  \
# 1       0   41       1   83807.86          0               1        112542.58
# 2       0   42       8  159660.80          1               0        113931.57
# 4       0   43       2  125510.82          1               1         79084.10
# 5       1   44       8  113755.78          1               0        149756.71
# 7       0   29       4  115046.74          1               0        119346.88
#
#    Exited
# 1       0
# 2       1
# 4       0
# 5       1
# 7       1

# %%
dataset_read.shape
# Out:
# (6383, 8)

# %%
#Rescaling the data 
Age_mean_val=dataset_read.Age.mean()
Age_mean_val
# Out:
# 39.19771267429108

# %%
dataset_read.Age=dataset_read.Age/Age_mean_val

# %%
Balance_mean_val=dataset_read.Balance.mean()
Balance_mean_val
# Out:
# 119827.49379288674

# %%
dataset_read.Balance=dataset_read.Balance/Balance_mean_val

# %%
EstimatedSalary_mean_val=dataset_read.EstimatedSalary.mean()
EstimatedSalary_mean_val
# Out:
# 100717.35295629001

# %%
dataset_read.EstimatedSalary=dataset_read.EstimatedSalary/EstimatedSalary_mean_val

# %%
Tenure_mean_val=dataset_read.Tenure.mean()
Tenure_mean_val
# Out:
# 4.979633401221996

# %%
dataset_read.Tenure=dataset_read.Tenure/Tenure_mean_val

# %%
# dataset after rescaling
dataset_read.head()
# Out:
#    Gender       Age    Tenure   Balance  HasCrCard  IsActiveMember  \
# 1       0  1.045979  0.200818  0.699404          0               1
# 2       0  1.071491  1.606544  1.332422          1               0
# 4       0  1.097003  0.401636  1.047429          1               1
# 5       1  1.122514  1.606544  0.949330          1               0
# 7       0  0.739839  0.803272  0.960103          1               0
#
#    EstimatedSalary  Exited
# 1         1.117410       0
# 2         1.131201       1
# 4         0.785208       0
# 5         1.486901       1
# 7         1.184968       1

# %%
# converting data in numpy array
import numpy as np
target=np.array(dataset_read.Exited)

pre_data=dataset_read.as_matrix(columns=dataset_read.columns[:-1])
# Out:
# /home/raj/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """

# %%
pre_data[0]
# Out:
# array([0.        , 1.0459794 , 0.200818  , 0.69940426, 0.        ,
#        1.        , 1.11741003])

# %%
predictor = Var(sy.FloatTensor(pre_data))
target = Var(sy.LongTensor(target))

# %%
# sending data to two virtual worker
predictor_MD_1 = predictor[0:5000].send(mobile_device_1)
target_MD_1 = target[0:5000].send(mobile_device_1)

predictor_MD_2 = predictor[5000:].send(mobile_device_2)
target_MD_2 = target[5000:].send(mobile_device_2)

# %%
# Model definition

input_size=7
num_classes=2
learning_rate=0.01
epochs=300

class LogisticRegression(nn.Module): 
    def __init__(self, input_size, num_classes): 
        super(LogisticRegression, self).__init__() 
        self.linear = nn.Linear(input_size, num_classes) 
  
    def forward(self, x): 
        out = self.linear(x) 
        return out
    
model = LogisticRegression(input_size, num_classes) 
#model=nn.Linear(input_size,num_classes)
# Loss and Optimizer 
# Softmax is internally computed. 

criterion = nn.CrossEntropyLoss() 
optimizer = optim.SGD(params=model.parameters(), lr = learning_rate)

# %%
# Training over distributed dataset
datasets = [(predictor_MD_1,target_MD_1),(predictor_MD_2,target_MD_2)]

for iter in range(epochs):
    for data, target in datasets:
           
            model.send(data.location)
            
            # update the model
            
            optimizer.zero_grad()
            pred = model(data)
            #print(pred)
            #print(target)
            
            loss = criterion(pred, target)
            loss.backward()
            model.get()
            optimizer.step()
            print(loss.get().data[0])
# Out:
# 0.7477648258209229
# 0.7365473508834839
# 0.7261958718299866
# 0.7158901691436768
# 0.7070816159248352
# 0.6975600719451904
# 0.6901471018791199
# 0.6813010573387146
# 0.6751525402069092
# 0.6668809056282043
# 0.6618748307228088
# 0.6540884971618652
# 0.6501137018203735
# 0.6427356600761414
# 0.6396939158439636
# 0.6326553225517273
# 0.6304564476013184
# 0.6236971616744995
# 0.622262716293335
# 0.6157307028770447
# 0.6149895191192627
# 0.6086391806602478
# 0.6085241436958313
# 0.6023189425468445
# 0.6027761697769165
# 0.5966811180114746
# 0.5976546406745911
# 0.5916453003883362
# 0.5930914878845215
# 0.5871419906616211
# 0.5890182256698608
# 0.5831102728843689
# 0.5853804349899292
# 0.5794960856437683
# 0.5821259021759033
# 0.5762515664100647
# 0.5792121291160583
# 0.5733364820480347
# 0.5765990018844604
# 0.570712685585022
# 0.5742517709732056
# 0.5683479309082031
# 0.5721433758735657
# 0.5662144422531128
# 0.5702434778213501
# 0.5642862915992737
# 0.5685329437255859
# 0.5625420808792114
# 0.5669878721237183
# 0.5609614849090576
# 0.5655932426452637
# 0.5595287084579468
# 0.5643298625946045
# 0.5582258701324463
# 0.5631853342056274
# 0.5570409297943115
# 0.5621449947357178
# 0.5559603571891785
# 0.5612002015113831
# 0.5549750328063965
# 0.5603398680686951
# 0.5540744066238403
# 0.559555172920227
# 0.5532494187355042
# 0.5341724753379822
# 0.5303248763084412
# 0.534101128578186
# 0.530271589756012
# 0.5340316891670227
# 0.5302174091339111
# 0.5339605212211609
# 0.5301645994186401
# 0.5338900685310364
# 0.5301106572151184
# 0.5338215827941895
# 0.5300573706626892
# 0.533751368522644
# 0.5300052762031555
# 0.5336810946464539
# 0.529952883720398
# 0.5336136221885681
# 0.529899001121521
# 0.5335431694984436
# 0.5298463106155396
# 0.5334754586219788
# 0.5297937393188477
# 0.533405601978302
# 0.5297417044639587
# 0.5333361625671387
# 0.5296894907951355
# 0.5332671403884888
# 0.5296375155448914
# 0.5331997275352478
# 0.5295854806900024
# 0.5331312417984009
# 0.529533326625824
# 0.533062219619751
# 0.5294819474220276
# 0.5329951047897339
# 0.5294298529624939
# 0.5329270958900452
# 0.5293790698051453
# 0.5328595042228699
# 0.5293275117874146
# 0.5327919125556946
# 0.5292760133743286
# 0.5327253341674805
# 0.5292255282402039
# 0.5326577425003052
# 0.5291749835014343
# 0.5325902104377747
# 0.5291240811347961
# 0.532522976398468
# 0.5290727615356445
# 0.5324576497077942
# 0.5290222764015198
# 0.5323891043663025
# 0.5289714336395264
# 0.5323241353034973
# 0.5289221405982971
# 0.5322571992874146
# 0.5288719534873962
# 0.5321905016899109
# 0.5288216471672058
# 0.5321255922317505
# 0.5287715792655945
# 0.5320590138435364
# 0.5287219285964966
# 0.5319926142692566
# 0.5286721587181091
# 0.5319269895553589
# 0.5286228656768799
# 0.5318619608879089
# 0.5285733938217163
# 0.5317981243133545
# 0.5285237431526184
# 0.5317322015762329
# 0.528474748134613
# 0.5316672921180725
# 0.528425931930542
# 0.5316024422645569
# 0.5283762812614441
# 0.5315373539924622
# 0.5283283591270447
# 0.5314720869064331
# 0.5282796621322632
# 0.5314086675643921
# 0.5282304883003235
# 0.5313448309898376
# 0.528182327747345
# 0.5312801003456116
# 0.5281340479850769
# 0.5312153697013855
# 0.5280858874320984
# 0.5311515927314758
# 0.5280376672744751
# 0.5310879349708557
# 0.5279903411865234
# 0.5310254693031311
# 0.5279422998428345
# 0.5309615731239319
# 0.5278937816619873
# 0.5308982729911804
# 0.52784663438797
# 0.530836284160614
# 0.527799129486084
# 0.5307715535163879
# 0.5277514457702637
# 0.5307089686393738
# 0.5277042388916016
# 0.530647337436676
# 0.5276572704315186
# 0.5305822491645813
# 0.5276097655296326
# 0.5305213332176208
# 0.5275633335113525

# %%
#testing model
p=model(predictor_MD_1.get())

# %%
_, predicted = sy.max(p.data, 1)

# %%
predicted
# Out:
#  0
#  0
#  0
# ⋮
#  0
#  0
#  0
# [syft.core.frameworks.torch.tensor.LongTensor of size 5000]

# %%
actual_val=target_MD_1.get()

# %%
actual_val
# Out:
# Variable containing:
#  0
#  1
#  0
# ⋮
#  0
#  0
#  0
# [syft.core.frameworks.torch.tensor.LongTensor of size 5000]

# %%
total=len(actual_val)
correct=0
for i in range(total):
     correct += (predicted[i] == actual_val[i]).sum()

# %%
#obtained accuracy
accuracy=100*(int(correct)/total)
accuracy
# Out:
# 4.02
